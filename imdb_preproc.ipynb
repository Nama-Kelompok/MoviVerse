# %%
import math
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('imdb_top_1000_with_wikidata_preprocessed_2.csv')
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 3  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 4  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title  Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption           1994           A    142.0  Drama
# 1  The Shawshank Redemption           1994           A    142.0  Drama
# 2  The Shawshank Redemption           1994           A    142.0  Drama
# 3  The Shawshank Redemption           1994           A    142.0  Drama
# 4             The Godfather           1972           A    175.0  Crime
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# ...

# %%
df['Runtime'] = df['Runtime'].astype(np.int64)

# %%
df['Meta_score'] = df['Meta_score'].astype("Int64")

# %%
tmp = np.mod(df['Gross'], 1)
tmp[(tmp != 0) & (~np.isnan(tmp))]
# Out:
# Series([], Name: Gross, dtype: float64)

# %%
df['Gross'] = df['Gross'].astype("Int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10164 entries, 0 to 10163
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    10164 non-null  object
#  1   Series_Title   10164 non-null  object
#  2   Released_Year  10164 non-null  int64
#  3   Certificate    9224 non-null   object
#  4   Runtime        10164 non-null  int64
#  5   Genre          10164 non-null  object
#  6   IMDB_Rating    10164 non-null  float64
#  7   Overview       10164 non-null  object
#  8   Meta_score     8584 non-null   Int64
#  9   Director       10164 non-null  object
#  10  Stars          10164 non-null  object
#  11  No_of_Votes    10164 non-null  int64
#  12  Gross          8436 non-null   Int64
#  13  wikidata_id    8904 non-null   object
# dtypes: Int64(2), float64(1), int64(3), object(8)
# memory usage: 1.1+ MB

# %%
# Save
df.to_csv('imdb_top_1000_with_wikidata_preprocessed_3.csv', index=False)

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 3  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 4  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title  Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption           1994           A      142  Drama
# 1  The Shawshank Redemption           1994           A      142  Drama
# 2  The Shawshank Redemption           1994           A      142  Drama
# 3  The Shawshank Redemption           1994           A      142  Drama
# 4             The Godfather           1972           A      175  Crime
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...          80
# ...
